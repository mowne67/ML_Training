# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg

# %%
img = mpimg.imread('frilled-lizard.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('tree.png')
imgplot = plt.imshow(img)
plt.show()
